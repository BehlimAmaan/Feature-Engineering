# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df['bill_lenght_mm']=df['bill_length_mm'].fillna(df['bill_length_mm'].mean())

# %%
df['bill_depth_mm']=df['bill_depth_mm'].fillna(df['bill_depth_mm'].mean())

# %%
df['body_mass_g']=df['body_mass_g'].fillna(df['body_mass_g'].mean())

# %%
df['sex'] = df['sex'].fillna(df['sex'].mode()[0])

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1       18.70000              181.0
# 1    Adelie  Torgersen            39.5       17.40000              186.0
# 2    Adelie  Torgersen            40.3       18.00000              195.0
# 3    Adelie  Torgersen             NaN       17.15117                NaN
# 4    Adelie  Torgersen            36.7       19.30000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN       17.15117                NaN
# 340  Gentoo     Biscoe            46.8       14.30000              215.0
# 341  Gentoo     Biscoe            50.4       15.70000              222.0
# 342  Gentoo     Biscoe            45.2       14.80000              212.0
# 343  Gentoo     Biscoe            49.9       16.10000              213.0
#
#      body_mass_g     sex  bill_lenght_mm
# 0    3750.000000    Male        39.10000
# 1    3800.000000  Female        39.50000
# 2    3250.000000  Female        40.30000
# 3    4201.754386    Male        43.92193
# 4    3450.000000  Female        36.70000
# ..           ...     ...             ...
# 339  4201.754386    Male        43.92193
# 340  4850.000000  Female        46.80000
# 341  5750.000000    Male        50.40000
# 342  5200.000000  Female        45.20000
# 343  5400.000000    Male        49.90000
#
# [344 rows x 8 columns]

# %%
df.drop('bill_lenght_mm_',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.drop('bill_lenght_mm_',axis=1,inplace=True)
#
# File d:\Udemy\ML Study Material\Feature Engineering\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File d:\Udemy\ML Study Material\Feature Engineering\venv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File d:\Udemy\ML Study Material\Feature Engineering\venv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File d:\Udemy\ML Study Material\Feature Engineering\venv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['bill_lenght_mm_'] not found in axis"

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1       18.70000              181.0
# 1    Adelie  Torgersen            39.5       17.40000              186.0
# 2    Adelie  Torgersen            40.3       18.00000              195.0
# 3    Adelie  Torgersen             NaN       17.15117                NaN
# 4    Adelie  Torgersen            36.7       19.30000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN       17.15117                NaN
# 340  Gentoo     Biscoe            46.8       14.30000              215.0
# 341  Gentoo     Biscoe            50.4       15.70000              222.0
# 342  Gentoo     Biscoe            45.2       14.80000              212.0
# 343  Gentoo     Biscoe            49.9       16.10000              213.0
#
#      body_mass_g     sex  bill_lenght_mm
# 0    3750.000000    Male        39.10000
# 1    3800.000000  Female        39.50000
# 2    3250.000000  Female        40.30000
# 3    4201.754386    Male        43.92193
# 4    3450.000000  Female        36.70000
# ..           ...     ...             ...
# 339  4201.754386    Male        43.92193
# 340  4850.000000  Female        46.80000
# 341  5750.000000    Male        50.40000
# 342  5200.000000  Female        45.20000
# 343  5400.000000    Male        49.90000
#
# [344 rows x 8 columns]

# %%
df.isnull().sum()
df.dropna(axis=1,inplace=True)
df
# Out:
#     species     island  bill_depth_mm  body_mass_g     sex  bill_lenght_mm
# 0    Adelie  Torgersen       18.70000  3750.000000    Male        39.10000
# 1    Adelie  Torgersen       17.40000  3800.000000  Female        39.50000
# 2    Adelie  Torgersen       18.00000  3250.000000  Female        40.30000
# 3    Adelie  Torgersen       17.15117  4201.754386    Male        43.92193
# 4    Adelie  Torgersen       19.30000  3450.000000  Female        36.70000
# ..      ...        ...            ...          ...     ...             ...
# 339  Gentoo     Biscoe       17.15117  4201.754386    Male        43.92193
# 340  Gentoo     Biscoe       14.30000  4850.000000  Female        46.80000
# 341  Gentoo     Biscoe       15.70000  5750.000000    Male        50.40000
# 342  Gentoo     Biscoe       14.80000  5200.000000  Female        45.20000
# 343  Gentoo     Biscoe       16.10000  5400.000000    Male        49.90000
#
# [344 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# species           0
# island            0
# bill_depth_mm     0
# body_mass_g       0
# sex               0
# bill_lenght_mm    0
# dtype: int64

# %%
sns.histplot(df['bill_lenght_mm'],kde=True)
# Out:
# <Axes: xlabel='bill_lenght_mm', ylabel='Count'>

# %%
df['species'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('')
plt.title('Penguin Species Distribution')
plt.show()

# %%
df.describe()
# Out:
#        bill_depth_mm  body_mass_g  bill_lenght_mm
# count     344.000000   344.000000      344.000000
# mean       17.151170  4201.754386       43.921930
# std         1.969027   799.613058        5.443643
# min        13.100000  2700.000000       32.100000
# 25%        15.600000  3550.000000       39.275000
# 50%        17.300000  4050.000000       44.250000
# 75%        18.700000  4750.000000       48.500000
# max        21.500000  6300.000000       59.600000
